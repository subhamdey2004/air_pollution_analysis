# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = '../data/processed/air_quality_cleaned.csv'
df = pd.read_csv(data_path)

# %%
city_cols = [col for col in df.columns if col.startswith("City_")]
df['City'] = df[city_cols].idxmax(axis=1).str.replace('City_', '')
df.head()
# Out:
#    PM2.5   PM10   NO2   NOx     NH3    CO    SO2     O3  Benzene  Toluene  \
# 0  65.37  72.38  8.07  8.57  13.395  0.64  16.31   8.02     1.63     4.34
# 1  56.28  72.38  8.02  8.51  13.395  0.60  18.93   6.20     1.52     3.74
# 2  48.17  72.38  8.00  8.55  13.395  0.65  18.99   7.97     1.23     4.74
# 3  33.56  72.38  7.89  8.56  13.395  0.72  11.28  10.18     0.61     3.85
# 4  31.30  72.38  8.10  8.49  13.395  0.55  10.29   7.44     0.52     2.31
#
#    ...  date_2020-06-23  date_2020-06-24  date_2020-06-25  date_2020-06-26  \
# 0  ...            False            False            False            False
# 1  ...            False            False            False            False
# 2  ...            False            False            False            False
# 3  ...            False            False            False            False
# 4  ...            False            False            False            False
#
#    date_2020-06-27  date_2020-06-28  date_2020-06-29  date_2020-06-30  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    date_2020-07-01    City
# 0            False  Aizawl
# 1            False  Aizawl
# 2            False  Aizawl
# 3            False  Aizawl
# 4            False  Aizawl
#
# [5 rows x 1967 columns]

# %%
print("Dataset shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nSummary Statistics:")
display(df.describe())
# Out:
# Dataset shape: (10926, 1967)
# Columns: ['PM2.5', 'PM10', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'City_Aizawl', 'City_Amaravati', 'City_Amritsar', 'City_Chandigarh', 'City_Chennai', 'City_Coimbatore', 'City_Delhi', 'City_Ernakulam', 'City_Gurugram', 'City_Guwahati', 'City_Hyderabad', 'City_Jaipur', 'City_Jorapokhar', 'City_Kochi', 'City_Kolkata', 'City_Lucknow', 'City_Mumbai', 'City_Patna', 'City_Shillong', 'City_Talcher', 'City_Thiruvananthapuram', 'City_Visakhapatnam', 'date_2015-01-02', 'date_2015-01-03', 'date_2015-01-04', 'date_2015-01-05', 'date_2015-01-06', 'date_2015-01-07', 'date_2015-01-08', 'date_2015-01-09', 'date_2015-01-10', 'date_2015-01-11', 'date_2015-01-12', 'date_2015-01-13', 'date_2015-01-14', 'date_2015-01-15', 'date_2015-01-16', 'date_2015-01-17', 'date_2015-01-18', 'date_2015-01-19', 'date_2015-01-20', 'date_2015-01-21', 'date_2015-01-22', 'date_2015-01-23', 'date_2015-01-24', 'date_2015-01-25', 'date_2015-01-26', 'date_2015-01-27', 'date_2015-01-28', 'date_2015-01-29', 'date_2015-01-30', 'date_2015-01-31', 'date_2015-02-01', 'date_2015-02-02', 'date_2015-02-03', 'date_2015-02-04', 'date_2015-02-05', 'date_2015-02-06', 'date_2015-02-07', 'date_2015-02-08', 'date_2015-02-09', 'date_2015-02-10', 'date_2015-02-11', 'date_2015-02-12', 'date_2015-02-13', 'date_2015-02-14', 'date_2015-02-15', 'date_2015-02-16', 'date_2015-02-17', 'date_2015-02-18', 'date_2015-02-19', 'date_2
#               PM2.5          PM10           NO2           NOx           NH3  \
# count  10926.000000  10926.000000  10926.000000  10926.000000  10926.000000
# mean      37.607246     65.211178     17.815038     19.268731     13.041588
# std       22.055680     42.203992     11.647746     13.767499     10.088482
# min        0.040000      0.420000      0.010000      0.000000      0.010000
# 25%       20.522500     31.580000      9.382500      8.852500      5.020000
# 50%       34.730000     54.590000     14.740000     16.505000     11.750000
# 75%       50.327500     86.717500     24.140000     26.630000     17.900000
# max      147.880000    234.510000     63.070000     65.410000     47.540000
#
#                  CO           SO2            O3       Benzene       Toluene  \
# count  10926.000000  10926.000000  10926.000000  10926.000000  10926.000000
# mean       0.741157      8.401679     30.069938      0.813746      2.244017
# std        0.503991      4.652358     16.158271      1.156725      2.708498
# min        0.000000      0.010000      0.010000      0.000000      0.000000
# 25%        0.390000      5.250000     17.820000      0.000000      0.000000
# 50%        0.680000      7.360000     28.800000      0.220000      1.110000
# 75%        1.037500     10.780000     39.727500      1.230000      3.830000
# max        2.370000     23.160000     77.470000      5.190000     10.870000
#
#              Xylene           AQI
# count  10926.000000  10926.000000
# mean       1.179577     93.502105
# std        1.246722     40.445444
# min        0.000000     14.000000
# 25%        0.180000     65.000000
# 50%        0.460000     85.000000
# 75%        2.140000    116.000000
# max        6.260000    221.000000

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['PM2.5'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of PM2.5')
plt.xlabel('PM2.5')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\deysu\AppData\Local\Temp\ipykernel_5972\2965755057.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='City', y='PM2.5', data=df)
plt.xticks(rotation=45)
plt.title('PM2.5 Levels Across Cities')
plt.show()
# Out:
# C:\Users\deysu\AppData\Local\Temp\ipykernel_5972\2971958835.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
numeric_cols = df.select_dtypes(include='number').columns  # Only numeric columns
plt.figure(figsize=(12,8))
sns.heatmap(df[numeric_cols].corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Pollutants')
plt.show()
# Out:
# C:\Users\deysu\AppData\Local\Temp\ipykernel_5972\3824141544.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    # Example: visualize first city
    city_choice = df['City'].unique()[0]
    df_city = df[df['City'] == city_choice]
    
    plt.figure(figsize=(14,6))
    sns.lineplot(x='Date', y='PM2.5', data=df_city)
    plt.title(f'PM2.5 Trend over Time in {city_choice}')
    plt.xlabel('Date')
    plt.ylabel('PM2.5')
    plt.show()

# %%
if 'AQI' in df.columns:
    plt.figure(figsize=(8,5))
    sns.countplot(x='AQI', data=df, palette='viridis', 
                  order=df['AQI'].value_counts().index)
    plt.title('Count of AQI Categories')
    plt.xlabel('AQI Category')
    plt.ylabel('Count')
    plt.show()
# Out:
# C:\Users\deysu\AppData\Local\Temp\ipykernel_5972\91488080.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='AQI', data=df, palette='viridis',
# C:\Users\deysu\AppData\Local\Temp\ipykernel_5972\91488080.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
